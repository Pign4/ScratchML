# %%
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# create random line
np.random.seed(3)
beta = np.random.randint(1,6,(2,))
print(beta)
X = np.linspace([1, 0],[1, 10],100)
y = X @ beta

# plot line
plt.plot(X[:,1],y,color="red")
plt.show()
# Out:
# [3 1]

# %%
# create noise
mu, sigma = 0, 1 # mean and standard deviation
noise = np.random.normal(mu, sigma, 100)

# plot noise
plt.hist(noise)
# Out:
# (array([ 7.,  9.,  8., 17., 16., 11., 21.,  7.,  2.,  2.]),
#  array([-2.07537215, -1.6219998 , -1.16862746, -0.71525511, -0.26188276,
#          0.19148959,  0.64486194,  1.09823428,  1.55160663,  2.00497898,
#          2.45835133]),
#  <a list of 10 Patch objects>)

# %%
# add noise to y
y_noise = y + noise

# plot y_noise
plt.scatter(X[:,1],y_noise, color="blue")

# %%
# estimate beta in order to minimize the square errors
beta_ = np.linalg.inv(X.T @ X) @ X.T @ y_noise
print(beta_)
# Out:
# [2.70718461 1.0526971 ]

# %%
# estimate y given beta_
y_ = X @ beta_

# %%
# plot y_ and y_noise
plt.scatter(X[:,1],y_noise,color="blue")
plt.plot(X[:,1],y_,color="orange", lw=3)

# %%
# compare original and regression line
plt.subplot(121)
plt.plot(X[:,1],y,color="red")
plt.title("Original")

plt.subplot(122)
plt.plot(X[:,1],y_,color="orange")
plt.title("Regression")
# Out:
# Text(0.5, 1.0, 'Regression')
