# %%
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# create random line
beta = np.random.randint(1,6,(2,))
print(beta)
X = np.linspace([1, 0],[1, 10],100)
y = X @ beta

# plot line
plt.plot(X[:,1],y,color="red")
plt.show()
# Out:
# [5 3]

# %%
# create noise
mu, sigma = 0, 1 # mean and standard deviation
noise = np.random.normal(mu, sigma, 100)

# plot noise
plt.hist(noise)
# Out:
# (array([ 3.,  7., 12., 12., 13., 15., 15., 14.,  2.,  7.]),
#  array([-2.03084591, -1.63288355, -1.2349212 , -0.83695884, -0.43899648,
#         -0.04103413,  0.35692823,  0.75489058,  1.15285294,  1.5508153 ,
#          1.94877765]),
#  <a list of 10 Patch objects>)

# %%
# add noise to y
y_noise = y + noise

# plot y_noise
plt.scatter(X[:,1],y_noise, color="blue")

# %%
# estimate beta in order to minimize the square errors
beta_ = np.linalg.inv(X.T @ X) @ X.T @ y_noise
print(beta_)
# Out:
# [5.00152756 2.99934192]

# %%
# estimate y given beta_
y_ = X @ beta_

# %%
# plot y_ and y_noise
plt.scatter(X[:,1],y_noise,color="blue")
plt.plot(X[:,1],y_,color="orange", lw=3)

# %%
# compare original and regression line
plt.subplot(121)
plt.plot(X[:,1],y,color="red")
plt.title("Original")

plt.subplot(122)
plt.plot(X[:,1],y_,color="orange")
plt.title("Regression")
# Out:
# Text(0.5, 1.0, 'Regression')
