# %%
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# create random line
beta = np.array([1, 2])
X = np.linspace([1, 0],[1, 10],100)
y = X @ beta

# plot line
plt.plot(X[:,1],y,color="red")
plt.show()

# %%
# create noise
mu, sigma = 0, 1 # mean and standard deviation
noise = np.random.normal(mu, sigma, 100)

# plot noise
plt.hist(noise)
# Out:
# (array([ 6.,  2.,  7., 20., 22., 25.,  5.,  8.,  4.,  1.]),
#  array([-2.35703995, -1.84956992, -1.34209989, -0.83462987, -0.32715984,
#          0.18031019,  0.68778022,  1.19525024,  1.70272027,  2.2101903 ,
#          2.71766033]),
#  <a list of 10 Patch objects>)

# %%
# add noise to y
y_noise = y + noise

# plot y_noise
plt.scatter(X[:,1],y_noise, color="blue")

# %%
# estimate beta in order to minimize the square errors
beta_ = np.linalg.inv(X.T @ X) @ X.T @ y_noise
print(beta_)
# Out:
# [1.07724815 1.99092421]

# %%
# estimate y given beta_
y_ = X @ beta_

# %%
# plot y_ and y_noise
plt.scatter(X[:,1],y_noise,color="blue")
plt.plot(X[:,1],y_,color="orange", lw=3)

# %%
# compare original and regression line
plt.subplot(121)
plt.plot(X[:,1],y,color="red")
plt.title("Original")

plt.subplot(122)
plt.plot(X[:,1],y_,color="orange")
plt.title("Regression")
# Out:
# Text(0.5, 1.0, 'Regression')
